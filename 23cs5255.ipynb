# %% [markdown]
# <a href="https://colab.research.google.com/github/girishnn/sanjay/blob/main/23cs5255.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/tip.csv')
print(df)
df.info()
df.describe()
df.head()
# Out:
#     week      day  n_peop    bill      tip
# 0      1  Tuesday    0.67   17.99      NaN
# 1      1  Tuesday    1.33   26.05   4.0000
# 2      1  Tuesday    5.33   79.49  14.3082
# 3      1  Tuesday    2.67   32.69   5.5000
# 4      1  Tuesday    1.33     NaN   6.0000
# ..   ...      ...     ...     ...      ...
# 90     3   Friday    1.33   25.04   6.0000
# 91     3   Friday    4.00   76.27  13.0000
# 92     3   Friday    1.33   24.21   3.7500
# 93     3   Friday    1.33   34.05   8.5000
# 94     3   Friday    8.67  115.39  20.7702
#
# [95 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    95 non-null     int64
#  1   day     95 non-null     object
#  2   n_peop  95 non-null     float64
#  3   bill    90 non-null     float64
#  4   tip     92 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# ...

# %%
dff=df.isna().sum()
dff
# Out:
# week      0
# day       0
# n_peop    0
# bill      5
# tip       3
# dtype: int64

# %%
new_df=df.fillna(0)
new_df
# Out:
#     week      day  n_peop    bill      tip
# 0      1  Tuesday    0.67   17.99   0.0000
# 1      1  Tuesday    1.33   26.05   4.0000
# 2      1  Tuesday    5.33   79.49  14.3082
# 3      1  Tuesday    2.67   32.69   5.5000
# 4      1  Tuesday    1.33    0.00   6.0000
# ..   ...      ...     ...     ...      ...
# 90     3   Friday    1.33   25.04   6.0000
# 91     3   Friday    4.00   76.27  13.0000
# 92     3   Friday    1.33   24.21   3.7500
# 93     3   Friday    1.33   34.05   8.5000
# 94     3   Friday    8.67  115.39  20.7702
#
# [95 rows x 5 columns]

# %%
x=df['bill']
y=df['tip']
plt.scatter(x,y)
plt.title('scatter of bill and tip')
plt.xlabel('bill')
plt.ylabel('tip')
plt.show()
